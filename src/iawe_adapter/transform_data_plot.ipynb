# %%
from nilm_pre_processing import NilmPreProcessing
import numpy as np
import pandas as pd
import os

# %%
nilm_pp = NilmPreProcessing()
base_path = "/opt/nilm-shared-data/nilm_device_detection/other_dataset/iawe/transform_data"

# %% [markdown]
# # Plot transform data

# %%
df = pd.read_csv(os.path.join(base_path, "air_conditioner_1_iawe.csv"))
nilm_pp.plot_data_with_time(device_name="Air conditioner 1", df=df, start=None, end=None)
# Out:
# /opt/miniconda3/envs/nilmtk-env/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df = pd.read_csv(os.path.join(base_path, "air_conditioner_2_iawe.csv"))
nilm_pp.plot_data_with_time(device_name="Air conditioner 2", df=df, start=None, end=None)
# Out:
# /opt/miniconda3/envs/nilmtk-env/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df = pd.read_csv(os.path.join(base_path, "clothes_iron_iawe.csv"))
print(len(df))
nilm_pp.plot_data_with_time(device_name="Clothes iron", df=df, start=0, end=None)
# Out:
# 3643

# %%
df = pd.read_csv(os.path.join(base_path, "clothes_iron_iawe.csv"))
print(len(df))
nilm_pp.plot_data_with_time(device_name="Clothes iron", df=df, start=0, end=200)
# Out:
# 3643

# %%
df = pd.read_csv(os.path.join(base_path, "computer_iawe.csv"))
nilm_pp.plot_data_with_time(device_name="Computer", df=df, start=0, end=3000)

# %%
df = pd.read_csv(os.path.join(base_path, "fridge_iawe.csv"))
nilm_pp.plot_data_with_time(device_name="Fridge", df=df, start=2200, end=3000)

# %%
df = pd.read_csv(os.path.join(base_path, "motor_iawe.csv"))
nilm_pp.plot_data_with_time(device_name="Motor", df=df, start=None, end=None)

# %%
nilm_pp.plot_data_with_time(device_name="Motor", df=df, start=4700, end=4800)

# %%
df = pd.read_csv(os.path.join(base_path, "television_iawe.csv"))
nilm_pp.plot_data_with_time(device_name="Television", df=df, start=0, end=2000)

# %%
df = pd.read_csv(os.path.join(base_path, "washing_machine_iawe.csv"))
print(len(df))
nilm_pp.plot_data_with_time(device_name="Washing Machine", df=df, start=None, end=None)
# Out:
# 15686

# %%
df = pd.read_csv(os.path.join(base_path, "wet_appliance_iawe.csv"))
print(len(df))
nilm_pp.plot_data_with_time(device_name="Wet appliance all data", df=df, start=None, end=None)
# Out:
# 1694622
# /opt/miniconda3/envs/nilmtk-env/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df = pd.read_csv(os.path.join(base_path, "wet_appliance_iawe.csv"))
print(len(df))
nilm_pp.plot_data_with_time(device_name="Wet appliance", df=df, start=0, end=1000)
# Out:
# 1694622
